# %%
import import_ipynb
from ipynb.fs.full.mindistance import *
from ipynb.fs.full.theatre_ranking import *
from ipynb.fs.full.Movie import *
from ipynb.fs.full.theatre import *

# %%
graph()

# %%
graph1()

# %%
while True:
    print("What recommendations do you want?\n1==>Top N best movies of current release\n2==>Top N best theatres\n3==>Theatre recommendation based on your location\n4==>Theatre Recommendation based on user preference\n5==>Top n best movie and its screening theatres\n6==>exit\n")
    userinput=int(input("Please enter your interest:"))
    if userinput==1:
        print(top_nmovies(int(input("Enter the number of best movie that you require: "))))
    elif userinput==2:
        print(top_ntheatre(int(input("Enter the number of best theatre  that you require: ")))["movie"])
    elif userinput==3:
        print(dist(str(input("Enter the your location in chennai to find the nearest theatre: "))))
    elif userinput==4:
        print(Theater_Recommendation(str(input("Enter your suggestion for theatre: "))))
    elif userinput==5:
        for i in top_nmovies(int(input("Enter the number of best movies you require: "))):
            print("Movie Name:",i)
            print(theatre_name(i),"\n")
    elif userinput==6:
        break
    else:
        print("Invalid Option")
        print("\n")
        pass
    print("\n")
# Out:
# What recommendations do you want?
# 1==>Top N best movies of current release
# 2==>Top N best theatres
# 3==>Theatre recommendation based on your location
# 4==>Theatre Recommendation based on user preference
# 5==>Top n best movie and its screening theatres
# 6==>exit
#
# Please enter your interest:3
# Enter the your location in chennai to find the nearest theatre: anna nagar
# [['AGS Cinemas Villivakkam', 2.102792104244461], ['AGS Cinemas Navalur', 2.102792104244461], ['VR Chennai Anna Nagar', 2.316140039163313]]
#
#
# What recommendations do you want?
# 1==>Top N best movies of current release
# 2==>Top N best theatres
# 3==>Theatre recommendation based on your location
# 4==>Theatre Recommendation based on user preference
# 5==>Top n best movie and its screening theatres
# 6==>exit
#
# Please enter your interest:6
